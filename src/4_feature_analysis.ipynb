# %%
import pandas as pd
import json

# %% [markdown]
# We have manually selected features to keep and feature to dispose by looking through their attributes and descriptions. We use this to update the df.

# %%
df = pd.read_csv('./data/data_cleaned.csv')
with open('./data/feature_selection.json') as schema_file:
    feature_selection = json.load(schema_file)

# print(df.columns)
# feature_selection
for feature, choice in feature_selection.items():
    if choice == 'remove':
        df.drop([feature], axis=1, inplace=True)
df.head()
# Out:
#    property_id year_ending nyc_borough_block_and_lot  \
# 0   21205224.0  2021-12-31                4006520042
# 1    2665352.0  2021-12-31              1-01206-0001
# 2    2665400.0  2021-12-31              1-01832-0043
# 3    2665405.0  2021-12-31              1-00142-0025
# 4    2665415.0  2021-12-31              1-02072-0039
#
#                                    address_1 postal_code  \
# 0                        36-16 Astoria Blvd.       11103
# 1                        70 West 93rd Street       10025
# 2                     28-50 West 97th Street       10025
# 3  310 Greenwich Street / 40 Harrison Street       10013
# 4                          87 Hamilton Place       10031
#
#   primary_property_type_self                 national_median_reference  \
# 0        Multifamily Housing  Fannie Mae Industry Survey - Multifamily
# 1        Multifamily Housing  Fannie Mae Industry Survey - Multifamily
# 2        Multifamily Housing  Fannie Mae Industry Survey - Multifamily
# 3        Multifamily Housing  Fannie Mae Industry Survey - Multifamily
# 4        Multifamily Housing  Fannie Mae Industry Survey - Multifamily
#
#    largest_property_use_type_1  year_built construction_status  ...  \
# 0                      25000.0      2010.0            Existing  ...
# 1                     260780.0      1970.0            Existing  ...
# 2                     324378.0      1943.0            Existing  ...
# 3                    1039841.0      1975.0            Existing  ...
# 4                      72662.0      1941.0            Existing  ...
#
#    default_values  temporary_values property_gfa_self_reported  \
# 0             Yes                No                    25000.0
# 1              No                No                   261980.0
# 2             Yes                No                   333342.0
# 3             Yes                No                  1112900.0
# 4              No                No                    72662.0
#
#    property_gfa_calculated last_modified_date_property  \
# 0                  34146.0     07/11/2022 11:06 AM EDT
# 1                 261980.0     09/12/2022 04:34 PM EDT
# 2                 363092.0     04/09/2022 06:13 PM EDT
# 3                1345900.0     09/12/2022 04:33 PM EDT
# 4                  72662.0     05/22/2022 10:41 PM EDT
#
#    last_modified_date_property_1  number_of_active_energy_meters  \
# 0        05/19/2022 09:25 AM EDT                             8.0
# 1        04/10/2022 03:59 PM EDT                             6.0
# 2        08/05/2014 10:15 PM EDT                             3.0
# 3        08/25/2019 09:27 AM EDT                             4.0
# 4        04/04/2020 11:47 PM EDT                            11.0
#
#    number_of_active_it_meters  generation_date  submission_date
# 0                         0.0       2022-09-26       2022-09-26
# 1                         0.0       2022-09-26       2022-09-26
# 2                         0.0       2022-09-26       2022-09-26
# 3                         0.0       2022-09-26       2022-09-26
# 4                         0.0       2022-09-26       2022-09-26
#
# [5 rows x 44 columns]

# %%
# Save results
df.to_csv('./data/data_cleaned2.csv',index=False)
# Get the schema of the DataFrame
schema = {
    column: str(dtype) 
    for column, dtype in zip(df.columns, df.dtypes)
}

# Write the schema to a JSON file
with open('./data/schema_cleaned2.json', 'w') as schema_file:
    json.dump(schema, schema_file, indent=4)
